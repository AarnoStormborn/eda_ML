# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
data = pd.read_csv("D:\Coding\Datasets\\titanic\\train.csv")

# %%
data.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
data.set_index("PassengerId", drop=True, inplace=True)

# %%
data.drop(["Ticket","Cabin"], axis = 1, inplace=True)

# %%
data[pd.isnull(data["Embarked"])]
# Out:
#                                                   Name  Pclass     Sex   Age  \
# PassengerId
# 62                                 Icard, Miss. Amelie       1  female  38.0
# 830          Stone, Mrs. George Nelson (Martha Evelyn)       1  female  62.0
#
#              SibSp  Parch  Fare Embarked  Survived
# PassengerId
# 62               0      0  80.0      NaN         1
# 830              0      0  80.0      NaN         1

# %%
data.drop([62,830], inplace=True)

# %%
data.head(10)
# Out:
#                                                           Name  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3                                       Heikkinen, Miss. Laina       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 5                                     Allen, Mr. William Henry       3
# 6                                             Moran, Mr. James       3
# 7                                      McCarthy, Mr. Timothy J       1
# 8                               Palsson, Master. Gosta Leonard       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)       2
#
#                 Sex   Age  SibSp  Parch     Fare Embarked  Survived
# PassengerId
# 1              male  22.0      1      0   7.2500        S         0
# ...

# %%
mean_age = data.Age.mean()
mean_age = int(mean_age)
mean_age
# Out:
# 29

# %%
data.Age.fillna(mean_age,inplace=True)

# %%
data.head(10)
# Out:
#                                                           Name  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3                                       Heikkinen, Miss. Laina       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 5                                     Allen, Mr. William Henry       3
# 6                                             Moran, Mr. James       3
# 7                                      McCarthy, Mr. Timothy J       1
# 8                               Palsson, Master. Gosta Leonard       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)       2
#
#                 Sex   Age  SibSp  Parch     Fare Embarked  Survived
# PassengerId
# 1              male  22.0      1      0   7.2500        S         0
# ...

# %%
data['Age'] = data.Age.astype("int64")

# %%
data.head()
# Out:
#                                                           Name  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3                                       Heikkinen, Miss. Laina       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 5                                     Allen, Mr. William Henry       3
#
#                 Sex  Age  SibSp  Parch     Fare Embarked  Survived
# PassengerId
# 1              male   22      1      0   7.2500        S         0
# 2            female   38      1      0  71.2833        C         1
# 3            female   26      0      0   7.9250        S         1
# 4            female   35      1      0  53.1000        S         1
# 5              male   35      0      0   8.0500        S         0

# %%
data.isna().sum()
# Out:
# Name        0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Survived    0
# dtype: int64

# %%
data["Age"].dtype
# Out:
# dtype('int64')

# %%
enc = preprocessing.LabelEncoder()
Gender = enc.fit_transform(data['Sex'])
Embarked_enc = enc.fit_transform(data['Embarked'])

# %%
Embarked_enc
# Out:
# array([2, 0, 2, 2, 2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2,
#        1, 2, 2, 2, 0, 2, 1, 2, 0, 0, 1, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0, 0,
#        1, 2, 1, 1, 0, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 0, 0, 2,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2,
#        0, 2, 2, 0, 2, 1, 2, 0, 2, 2, 2, 0, 2, 2, 0, 1, 2, 0, 2, 0, 2, 2,
#        2, 2, 0, 2, 2, 2, 0, 0, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2,
#        0, 2, 2, 2, 0, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 0, 0, 1, 2, 1,
#        2, 2, 2, 2, 0, 2, 2, 2, 0, 1, 0, 2, 2, 2, 2, 1, 0, 2, 2, 0, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 1, 2,
#        2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 0, 2, 1, 2, 2, 2, 1,
#        2, 2, 2, 2, 2, 2, 2, 2, 0, 1, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 0, 2,
# ...

# %%
data.drop(["Sex","Embarked"], axis = 1, inplace=True)

# %%
data['Gender'] = pd.Series(Gender)
data['Embarked'] = pd.Series(Embarked_enc)

# %%
data.head()
# Out:
#                                                           Name  Pclass  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris       3   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...       1   38
# 3                                       Heikkinen, Miss. Laina       3   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)       1   35
# 5                                     Allen, Mr. William Henry       3   35
#
#              SibSp  Parch     Fare  Survived  Gender  Embarked
# PassengerId
# 1                1      0   7.2500         0     0.0       0.0
# 2                1      0  71.2833         1     0.0       2.0
# 3                0      0   7.9250         1     0.0       2.0
# 4                1      0  53.1000         1     1.0       2.0
# 5                0      0   8.0500         0     1.0       1.0

# %%
data.isna().sum()
# Out:
# Name        0
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Survived    0
# Gender      3
# Embarked    3
# dtype: int64

# %%
data[pd.isnull(data["Gender"])]
# Out:
#                                                  Name  Pclass  Age  SibSp  \
# PassengerId
# 889          Johnston, Miss. Catherine Helen "Carrie"       3   29      1
# 890                             Behr, Mr. Karl Howell       1   26      0
# 891                               Dooley, Mr. Patrick       3   32      0
#
#              Parch   Fare  Survived  Gender  Embarked
# PassengerId
# 889              2  23.45         0     NaN       NaN
# 890              0  30.00         1     NaN       NaN
# 891              0   7.75         0     NaN       NaN

# %%
data.drop([889,890,891],inplace=True)

# %%
data.isna().sum()
# Out:
# Name        0
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Survived    0
# Gender      0
# Embarked    0
# dtype: int64

# %%
data['Gender'] = data.Gender.astype("int64")
data['Embarked'] = data.Embarked.astype("int64")

# %%
df = data[["Name","Pclass","Age","SibSp","Parch","Fare","Gender","Embarked","Survived"]]

# %%
df.head(10)
# Out:
#                                                           Name  Pclass  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris       3   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...       1   38
# 3                                       Heikkinen, Miss. Laina       3   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)       1   35
# 5                                     Allen, Mr. William Henry       3   35
# 6                                             Moran, Mr. James       3   29
# 7                                      McCarthy, Mr. Timothy J       1   54
# 8                               Palsson, Master. Gosta Leonard       3    2
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3   27
# 10                         Nasser, Mrs. Nicholas (Adele Achem)       2   14
#
#              SibSp  Parch     Fare  Gender  Embarked  Survived
# PassengerId
# ...

# %%
X = df.iloc[:,1:7]
Y = df.iloc[:,7]

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
model = GaussianNB()

# %%
clf = svm.SVC()
clf.fit(X,Y)
# Out:
# SVC()

# %%
test = pd.read_csv("D:\Coding\Datasets\\titanic\\test.csv")

# %%
test.head()
# Out:
#    PassengerId                                          Name  Pclass     Sex  \
# 0          892                              Kelly, Mr. James       3    male
# 1          893              Wilkes, Mrs. James (Ellen Needs)       3  female
# 2          894                     Myles, Mr. Thomas Francis       2    male
# 3          895                              Wirz, Mr. Albert       3    male
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
#test.set_index("PassengerId", drop=True, inplace=True)

# %%
test.drop(["Ticket","Cabin"], axis = 1, inplace=True)

# %%
test[pd.isnull(test['Fare'])]
# Out:
#      PassengerId                Name  Pclass   Sex   Age  SibSp  Parch  Fare  \
# 152         1044  Storey, Mr. Thomas       3  male  60.5      0      0   NaN
#
#     Embarked
# 152        S

# %%
test.drop(152,inplace=True)

# %%
mean_age_test = test.Age.mean()
mean_age_test = int(mean_age_test)

# %%
test.Age.fillna(mean_age_test,inplace=True)

# %%
test['Age'] = test.Age.astype("int64")

# %%
test.head()
# Out:
#    PassengerId                                          Name  Pclass     Sex  \
# 0          892                              Kelly, Mr. James       3    male
# 1          893              Wilkes, Mrs. James (Ellen Needs)       3  female
# 2          894                     Myles, Mr. Thomas Francis       2    male
# 3          895                              Wirz, Mr. Albert       3    male
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3  female
#
#    Age  SibSp  Parch     Fare Embarked
# 0   34      0      0   7.8292        Q
# 1   47      1      0   7.0000        S
# 2   62      0      0   9.6875        Q
# 3   27      0      0   8.6625        S
# 4   22      1      1  12.2875        S

# %%
gender_test = enc.fit_transform(test['Sex'])
Embarked_enc_test = enc.fit_transform(test['Embarked'])

# %%
test['Gender_encoded'] = pd.Series(gender_test)
test['Embarked_encoded'] = pd.Series(Embarked_enc_test)

# %%
gender_test.shape
# Out:
# (417,)

# %%
#test.drop(["Gender_encoded","Embarked_encoded"],axis = 1, inplace= True)

# %%
test.head(10)
# Out:
#    PassengerId                                          Name  Pclass     Sex  \
# 0          892                              Kelly, Mr. James       3    male
# 1          893              Wilkes, Mrs. James (Ellen Needs)       3  female
# 2          894                     Myles, Mr. Thomas Francis       2    male
# 3          895                              Wirz, Mr. Albert       3    male
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3  female
# 5          897                    Svensson, Mr. Johan Cervin       3    male
# 6          898                          Connolly, Miss. Kate       3  female
# 7          899                  Caldwell, Mr. Albert Francis       2    male
# 8          900     Abrahim, Mrs. Joseph (Sophie Halaut Easu)       3  female
# 9          901                       Davies, Mr. John Samuel       3    male
#
#    Age  SibSp  Parch     Fare Embarked  Gender_encoded  Embarked_encoded
# ...

# %%
test.isna().sum()
# Out:
# PassengerId         0
# Name                0
# Pclass              0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Fare                0
# Embarked            0
# Gender_encoded      1
# Embarked_encoded    1
# dtype: int64

# %%
test.drop(417,inplace=True)

# %%
test['Gender_encoded'] = test.Gender_encoded.astype("int64")
test['Embarked_encoded'] = test.Embarked_encoded.astype("int64")

# %%
test.drop(["Sex","Embarked"], axis = 1, inplace=True)

# %%
test.head()
# Out:
#    PassengerId                                          Name  Pclass  Age  \
# 0          892                              Kelly, Mr. James       3   34
# 1          893              Wilkes, Mrs. James (Ellen Needs)       3   47
# 2          894                     Myles, Mr. Thomas Francis       2   62
# 3          895                              Wirz, Mr. Albert       3   27
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3   22
#
#    SibSp  Parch     Fare  Gender  Embarked
# 0      0      0   7.8292       1         1
# 1      1      0   7.0000       0         2
# 2      0      0   9.6875       1         1
# 3      0      0   8.6625       1         2
# 4      1      1  12.2875       0         2

# %%
test.rename(columns={"Gender_encoded":"Gender","Embarked_encoded":"Embarked"}, inplace=True)

# %%
X_test = test.iloc[:,2:8]
Y_test = test.iloc[:,8]

# %%
clf.score(X_test, Y_test)
# Out:
# 0.6442307692307693
